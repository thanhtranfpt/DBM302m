# %%
import pandas as pd

# %%
df = pd.read_csv('plants.csv', encoding='ANSI')
df.head()
# Out:
#                      name co dengl ca ga ct pr lb tx la  ... fl wy on ok oh  \
# 0                  abelia  n     n  n  n  n  n  n  n  n  ...  y  n  n  n  n
# 1    abelia x grandiflora  n     n  n  n  n  n  n  n  n  ...  y  n  n  n  n
# 2             abelmoschus  n     n  n  n  y  y  n  n  y  ...  y  n  n  n  n
# 3  abelmoschus esculentus  n     n  n  n  y  y  n  n  y  ...  y  n  n  n  n
# 4   abelmoschus moschatus  n     n  n  n  n  y  n  n  n  ...  n  n  n  n  n
#
#   sk sc ky or sd
# 0  n  n  n  n  n
# 1  n  n  n  n  n
# 2  n  y  y  n  n
# 3  n  y  y  n  n
# 4  n  n  n  n  n
#
# [5 rows x 70 columns]

# %%
df = df.T
df
# Out:
#         0                     1            2                       3      \
# name   abelia  abelia x grandiflora  abelmoschus  abelmoschus esculentus
# co          n                     n            n                       n
# dengl       n                     n            n                       n
# ca          n                     n            n                       n
# ga          n                     n            n                       n
# ...       ...                   ...          ...                     ...
# sk          n                     n            n                       n
# sc          n                     n            y                       y
# ky          n                     n            y                       y
# or          n                     n            n                       n
# sd          n                     n            n                       n
#
#                        4      5           6               7      \
# ...

# %%
df.columns = df.iloc[0]
df
# Out:
# name   abelia  abelia x grandiflora  abelmoschus  abelmoschus esculentus  \
# name   abelia  abelia x grandiflora  abelmoschus  abelmoschus esculentus
# co          n                     n            n                       n
# dengl       n                     n            n                       n
# ca          n                     n            n                       n
# ga          n                     n            n                       n
# ...       ...                   ...          ...                     ...
# sk          n                     n            n                       n
# sc          n                     n            y                       y
# ky          n                     n            y                       y
# or          n                     n            n                       n
# sd          n                     n            n                       n
#
# name   abelmoschus moschatus  abies  abies alba  abies amabilis  \
# ...

# %%
df = df[1:]
df
# Out:
# name  abelia abelia x grandiflora abelmoschus abelmoschus esculentus  \
# co         n                    n           n                      n
# dengl      n                    n           n                      n
# ca         n                    n           n                      n
# ga         n                    n           n                      n
# ct         n                    n           y                      y
# ...      ...                  ...         ...                    ...
# sk         n                    n           n                      n
# sc         n                    n           y                      y
# ky         n                    n           y                      y
# or         n                    n           n                      n
# sd         n                    n           n                      n
#
# name  abelmoschus moschatus abies abies alba abies amabilis abies balsamea  \
# ...

# %%
item_names = df.columns[1:]
item_names
# Out:
# Index(['abelia x grandiflora', 'abelmoschus', 'abelmoschus esculentus',
#        'abelmoschus moschatus', 'abies', 'abies alba', 'abies amabilis',
#        'abies balsamea', 'abies balsamea var. balsamea',
#        'abies balsamea var. phanerolepis',
#        ...
#        'zoysia tenuifolia', 'zuckia', 'zuckia brandegeei',
#        'zuckia brandegeei var. arizonica', 'zuckia brandegeei var. brandegeei',
#        'zuckia brandegeei var. plummeri', 'zygophlebia',
#        'zygophlebia sectifrons', 'zygophyllum', 'zygophyllum fabago'],
#       dtype='object', name='name', length=34780)

# %%
len(item_names)
# Out:
# 34780

# %%
from tqdm.notebook import tqdm

# %%
items_list = []


for idx, row in tqdm(df.iterrows(), total=len(df), desc="Processing Rows", unit="row"):
    items = []
    for item_index in range(len(item_names)):
        if row[item_names[item_index]] == 'y':
            items.append(item_index)

    items_list.append(items)
# Out:
# Processing Rows:   0%|          | 0/69 [00:00<?, ?row/s]

# %%
for items in items_list[:5]:
    print(len(items), items)
# Out:
# 5465 [4, 11, 12, 17, 18, 19, 25, 30, 32, 33, 34, 42, 45, 57, 67, 74, 78, 187, 193, 196, 198, 200, 201, 206, 209, 210, 212, 228, 234, 235, 244, 254, 255, 256, 261, 267, 272, 274, 275, 276, 277, 278, 281, 286, 287, 288, 289, 290, 293, 295, 337, 339, 340, 356, 358, 370, 371, 375, 386, 387, 429, 430, 432, 467, 468, 472, 474, 530, 566, 569, 577, 581, 587, 591, 593, 600, 602, 653, 663, 689, 694, 695, 696, 698, 699, 701, 702, 703, 706, 708, 712, 721, 727, 728, 729, 730, 731, 732, 733, 734, 735, 747, 748, 753, 755, 756, 763, 764, 766, 769, 770, 795, 797, 820, 821, 822, 824, 825, 826, 828, 839, 840, 841, 844, 850, 852, 853, 855, 856, 858, 859, 860, 861, 863, 864, 865, 868, 869, 876, 877, 878, 879, 880, 881, 884, 887, 904, 905, 917, 918, 920, 942, 944, 945, 964, 971, 1002, 1003, 1005, 1016, 1054, 1055, 1056, 1060, 1062, 1080, 1081, 1082, 1084, 1085, 1086, 1088, 1089, 1092, 1152, 1153, 1154, 1155, 1157, 1159, 1164, 1166, 1167, 1170, 1191, 1196, 1198, 1200, 1203, 1210, 1215, 1224, 1225, 1227, 12
# ...

# %%
# Your list
my_list = items_list

# Specify the file path
file_path = 'items_list.txt'

# Open the file in write mode
with open(file_path, 'w') as file:
    # Write each element of the list to the file
    for item in my_list:
        file.write(str(item) + '\n')

print(f'The list has been saved to {file_path}')
# Out:
# The list has been saved to items_list.txt

# %%
# Your list
my_list = item_names

# Specify the file path
file_path = 'item_names.txt'

# Open the file in write mode
with open(file_path, 'w') as file:
    # Write each element of the list to the file
    for item in my_list:
        file.write(str(item) + '\n')

print(f'The list has been saved to {file_path}')
# Out:
# The list has been saved to item_names.txt

# %%
# Specify the file path
file_path = 'item_names.txt'

# Open the file in read mode
with open(file_path, 'r') as file:
    # Read lines from the file and strip newline characters
    my_list = [line.strip() for line in file.readlines()]

print('List loaded from file:')
print(my_list)
# Out:
# List loaded from file:
# ...

# %%
# Specify the file path
file_path = 'items_list.txt'

# Open the file in read mode
with open(file_path, 'r') as file:
    # Read lines from the file and strip newline characters
    my_list = [line.strip() for line in file.readlines()]

print('List loaded from file:')
# Out:
# List loaded from file:

# %%
for i in my_list[:5]:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
from apriori_python import apriori

# %%
freq_items, rules = apriori(itemSetList=items_list, minSup=0.5, minConf=0.7)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "n:\envs\data_science\Lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Thanh Tran\AppData\Local\Temp\ipykernel_5152\4057607201.py", line 1, in <module>
#     freq_items, rules = apriori(itemSetList=items_list, minSup=0.5, minConf=0.7)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "n:\envs\data_science\Lib\site-packages\apriori_python\apriori.py", line 28, in apriori
#     currentLSet = getAboveMinSup(
#                   ^^^^^^^^^^^^^^^
#   File "n:\envs\data_science\Lib\site-packages\apriori_python\utils.py", line -1, in getAboveMinSup
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
for key in freq_items:
    print(key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 for key in freq_items:
#       2     print(key)
#
# NameError: name 'freq_items' is not defined
