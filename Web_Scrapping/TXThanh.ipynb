# %%
import pandas as pd

# %%
df = pd.read_csv('K:\LEARN AI FPT\TERM 7\DBM302m - Data Mining_Khai phá dữ liệu\Web_Scrapping\VietnamWithInterpretations_20200323_dryad_v2.csv', sep='\t')

# %%
df
# Out:
#       Country                                        SiteName  District  \
# 0     Vietnam              CPCP civet restaurant confiscation  Nho Quan
# 1     Vietnam              CPCP civet restaurant confiscation  Nho Quan
# 2     Vietnam              CPCP civet restaurant confiscation  Nho Quan
# 3     Vietnam              CPCP civet restaurant confiscation  Nho Quan
# 4     Vietnam              CPCP civet restaurant confiscation  Nho Quan
# ...       ...                                             ...       ...
# 4617  Vietnam  Cuc Phuong Natinal Park - Nho Quan - Ninh Binh  Nho Quan
# 4618  Vietnam  Cuc Phuong Natinal Park - Nho Quan - Ninh Binh  Nho Quan
# 4619  Vietnam  Cuc Phuong Natinal Park - Nho Quan - Ninh Binh  Nho Quan
# 4620  Vietnam  Cuc Phuong Natinal Park - Nho Quan - Ninh Binh  Nho Quan
# 4621  Vietnam  Cuc Phuong Natinal Park - Nho Quan - Ninh Binh  Nho Quan
#
#       StateProv  SiteLatitude  SiteLongitude  \
# 0     Ninh Binh         20.32         105.61
# ...

# %%
df.dtypes
# Out:
# Country                       object
# SiteName                      object
# District                      object
# StateProv                     object
# SiteLatitude                 float64
# SiteLongitude                float64
# EventName                     object
# DomesticAnimals               object
# AnimalID                      object
# TaxaGroup                     object
# SpeciesScientificName         object
# CommonName                    object
# CommonNameFieldMorphology     object
# IDCertainty                   object
# Order                         object
# Family                        object
# Genus                         object
# SampleDate                    object
# SpecimenID                    object
# SpecimenType                  object
# TestType                      object
# TestRequested                 object
# TestRequestedProtocol         object
# ConfirmationResult            object
# Sequence                      object
# ...
